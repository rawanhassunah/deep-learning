# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [01:09, 452kB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %%
int_words
# Out:
# [5233,
#  3080,
#  11,
#  5,
#  194,
#  1,
#  3133,
#  45,
#  58,
#  155,
#  127,
#  741,
#  476,
#  10571,
#  133,
#  0,
#  27349,
#  1,
#  0,
#  102,
#  854,
#  2,
#  0,
#  15067,
#  58112,
#  1,
#  0,
#  150,
#  854,
#  3580,
#  0,
#  194,
#  10,
#  190,
#  58,
#  4,
#  5,
#  10712,
#  214,
#  6,
#  1324,
#  104,
#  454,
#  19,
#  58,
#  2731,
#  362,
#  6,
#  3672,
#  0,
#  708,
#  1,
#  371,
#  26,
#  40,
#  36,
#  53,
#  539,
#  97,
#  11,
#  5,
#  1423,
#  2757,
#  18,
#  567,
#  686,
#  7088,
#  0,
#  247,
#  5233,
#  10,
#  1052,
#  27,
#  0,
#  320,
#  248,
#  44611,
#  2877,
#  792,
#  186,
#  5233,
#  11,
#  5,
#  200,
#  602,
#  10,
#  0,
#  1134,
#  19,
#  2621,
#  25,
#  8983,
#  2,
#  279,
#  31,
#  4147,
#  141,
#  59,
#  25,
#  6437,
#  4186,
#  1,
#  153,
#  32,
#  362,
#  5233,
#  36,
#  1137,
#  6,
#  447,
#  344,
#  1818,
#  19,
#  4860,
#  0,
#  6753,
#  1,
#  7573,
#  1774,
#  566,
#  0,
#  93,
#  0,
#  247,
#  11064,
#  11,
#  51,
#  7088,
#  89,
#  26,
#  270,
#  37,
#  5948,
#  4861,
#  20299,
#  28,
#  53721,
#  41,
#  317,
#  5,
#  25636,
#  527,
#  7573,
#  371,
#  4,
#  258,
#  1,
#  153,
#  25,
#  1206,
#  11,
#  7573,
#  200,
#  1576,
#  2,
#  15200,
#  332,
#  1774,
#  7088,
#  4860,
#  344,
#  764,
#  160,
#  406,
#  5690,
#  755,
#  1,
#  4105,
#  1131,
#  4331,
#  1536,
#  2,
#  567,
#  8117,
#  98,
#  5233,
#  10,
#  51,
#  1407,
#  686,
#  18,
#  153,
#  26,
#  10,
#  155,
#  7088,
#  36,
#  2033,
#  1423,
#  8174,
#  1,
#  153,
#  46,
#  693,
#  6,
#  31,
#  5,
#  4148,
#  246,
#  371,
#  76,
#  948,
#  78,
#  310,
#  30,
#  4778,
#  371,
#  507,
#  139,
#  2312,
#  3553,
#  364,
#  23,
#  1821,
#  6,
#  1902,
#  59,
#  10,
#  36,
#  8399,
#  78,
#  310,
#  5,
#  246,
#  371,
#  507,
#  31,
#  753,
#  78,
#  1732,
#  2,
#  8040,
#  24172,
#  2,
#  275,
#  1693,
#  19,
#  151,
#  1032,
#  95,
#  224,
#  371,
#  17,
#  1813,
#  24,
#  4778,
#  1556,
#  51,
#  8118,
#  1465,
#  24172,
#  2,
#  12743,
#  4,
#  6130,
#  19,
#  4187,
#  21148,
#  2427,
#  39,
#  16455,
#  2,
#  7239,
#  861,
#  1,
#  1193,
#  10207,
#  2514,
#  28,
#  15068,
#  187,
#  2,
#  48,
#  1123,
#  912,
#  6,
#  1049,
#  467,
#  12297,
#  7088,
#  133,
#  0,
#  0,
#  11064,
#  3055,
#  2,
#  12060,
#  734,
#  4778,
#  6598,
#  4,
#  14622,
#  27,
#  450,
#  485,
#  24172,
#  198,
#  295,
#  948,
#  4,
#  20027,
#  20300,
#  1,
#  53722,
#  300,
#  6,
#  24172,
#  20300,
#  16456,
#  0,
#  30106,
#  1,
#  0,
#  93,
#  44,
#  3832,
#  2,
#  53723,
#  2,
#  3807,
#  0,
#  3412,
#  1,
#  0,
#  1776,
#  187,
#  1,
#  0,
#  625,
#  0,
#  13141,
#  1,
#  3,
#  21,
#  90,
#  122,
#  284,
#  25,
#  243,
#  232,
#  6,
#  31,
#  436,
#  26184,
#  1,
#  173,
#  5233,
#  7699,
#  2534,
#  4,
#  29,
#  95,
#  1,
#  289,
#  602,
#  4308,
#  19,
#  0,
#  13141,
#  16456,
#  49,
#  187,
#  117,
#  46,
#  359,
#  19,
#  0,
#  384,
#  242,
#  96,
#  31,
#  5234,
#  34,
#  331,
#  2723,
#  18,
#  0,
#  838,
#  1376,
#  27,
#  32,
#  8761,
#  46,
#  6470,
#  34,
#  3243,
#  0,
#  27349,
#  28,
#  551,
#  42432,
#  39,
#  30,
#  127,
#  53724,
#  435,
#  84,
#  0,
#  64,
#  1,
#  0,
#  102,
#  462,
#  83,
#  2,
#  25,
#  232,
#  18,
#  47,
#  11,
#  26184,
#  1,
#  173,
#  5233,
#  4,
#  0,
#  173,
#  839,
#  0,
#  45,
#  6,
#  89,
#  0,
#  194,
#  6,
#  1014,
#  1043,
#  42,
#  69,
#  4861,
#  17,
#  936,
#  14920,
#  4571,
#  164,
#  4,
#  29,
#  40561,
#  11815,
#  22892,
#  259,
#  1225,
#  58113,
#  3,
#  22,
#  7,
#  16,
#  99,
#  35,
#  628,
#  0,
#  2662,
#  63,
#  371,
#  33,
#  48,
#  75,
#  93,
#  687,
#  14777,
#  4044,
#  28,
#  817,
#  917,
#  11,
#  101,
#  4,
#  11064,
#  2534,
#  362,
#  5,
#  6054,
#  2,
#  662,
#  4,
#  0,
#  63,
#  701,
#  435,
#  40,
#  4218,
#  1289,
#  19,
#  35,
#  10,
#  30,
#  4778,
#  2,
#  94,
#  25,
#  49,
#  29,
#  5212,
#  4,
#  3,
#  22,
#  8,
#  16,
#  4,
#  0,
#  5348,
#  1,
#  0,
#  150,
#  854,
#  467,
#  12297,
#  334,
#  30,
#  17194,
#  2434,
#  200,
#  1293,
#  141,
#  12297,
#  215,
#  37,
#  89,
#  0,
#  247,
#  5233,
#  55,
#  116,
#  7088,
#  38,
#  1206,
#  32,
#  197,
#  11,
#  0,
#  45,
#  181,
#  4778,
#  529,
#  2,
#  12297,
#  11,
#  0,
#  1834,
#  1,
#  1912,
#  5233,
#  41,
#  34,
#  32,
#  228,
#  75,
#  4778,
#  435,
#  733,
#  2399,
#  2,
#  0,
#  194,
#  17,
#  86,
#  1073,
#  11,
#  30,
#  14022,
#  30107,
#  18,
#  0,
#  12061,
#  58114,
#  34,
#  50,
#  2419,
#  616,
#  4,
#  0,
#  150,
#  854,
#  0,
#  45,
#  567,
#  8716,
#  4778,
#  2935,
#  1033,
#  14497,
#  26,
#  10,
#  636,
#  359,
#  19,
#  26,
#  5385,
#  154,
#  191,
#  2935,
#  1033,
#  14497,
#  334,
#  153,
#  10,
#  917,
#  4,
#  3,
#  12,
#  20,
#  7,
#  19,
#  0,
#  194,
#  4778,
#  17,
#  989,
#  11,
#  5,
#  567,
#  1606,
#  26,
#  10,
#  13,
#  32,
#  890,
#  19,
#  47,
#  848,
#  14497,
#  11,
#  0,
#  1834,
#  1,
#  173,
#  4778,
#  208,
#  4,
#  153,
#  10,
#  917,
#  14497,
#  5463,
#  23,
#  0,
#  419,
#  12953,
#  917,
#  10,
#  6878,
#  4,
#  32,
#  139,
#  35,
#  1346,
#  0,
#  2878,
#  1,
#  15068,
#  917,
#  154,
#  99,
#  3465,
#  38,
#  652,
#  445,
#  6,
#  89,
#  2,
#  3133,
#  43,
#  917,
#  11,
#  46,
#  3591,
#  54,
#  11,
#  15347,
#  1555,
#  13,
#  2965,
#  4,
#  44,
#  258,
#  14497,
#  1164,
#  153,
#  35,
#  88,
#  3221,
#  1131,
#  52,
#  38,
#  751,
#  445,
#  6,
#  89,
#  1049,
#  522,
#  2,
#  1791,
#  4,
#  5805,
#  23,
#  1556,
#  1,
#  5128,
#  2,
#  1293,
#  14497,
#  14,
#  2654,
#  1,
#  11064,
#  33,
#  35,
#  88,
#  29372,
#  966,
#  30,
#  1334,
#  518,
#  99,
#  1131,
#  2,
#  308,
#  159,
#  512,
#  0,
#  805,
#  1,
#  43,
#  1258,
#  218,
#  1258,
#  1037,
#  33,
#  1391,
#  0,
#  908,
#  1,
#  741,
#  64,
#  966,
#  4,
#  442,
#  32,
#  73,
#  2913,
#  19,
#  75,
#  3,
#  73,
#  2965,
#  27,
#  0,
#  1258,
#  1,
#  275,
#  1555,
#  159,
#  4319,
#  2518,
#  498,
#  4,
#  727,
#  10638,
#  18741,
#  30,
#  762,
#  246,
#  986,
#  73,
#  31,
#  177,
#  97,
#  6,
#  740,
#  3272,
#  23,
#  912,
#  6,
#  0,
#  362,
#  1,
#  442,
#  14497,
#  14,
#  948,
#  39,
#  2025,
#  222,
#  150,
#  741,
#  476,
#  1818,
#  2,
#  29,
#  2985,
#  39,
#  1021,
#  4,
#  0,
#  854,
#  1,
#  3,
#  12,
#  20,
#  12,
#  4,
#  302,
#  14497,
#  14,
#  602,
#  1,
#  917,
#  10,
#  647,
#  26,
#  17,
#  347,
#  4,
#  5,
#  112,
#  1,
#  311,
#  79,
#  29,
#  3567,
#  2,
#  59,
#  25,
#  6437,
#  4186,
#  1,
#  47,
#  1,
#  29,
#  948,
#  13,
#  50,
#  2158,
#  1589,
#  67,
#  621,
#  2749,
#  26185,
#  14,
#  15643,
#  4,
#  29,
#  0,
#  10464,
#  2,
#  44,
#  199,
#  26185,
#  1460,
#  19,
#  51,
#  636,
#  1045,
#  344,
#  1774,
#  133,
#  0,
#  2581,
#  1,
#  93,
#  917,
#  11,
#  5,
#  244,
#  389,
#  445,
#  4,
#  152,
#  2,
#  0,
#  147,
#  2581,
#  1,
#  371,
#  39,
#  4579,
#  20847,
#  28,
#  9216,
#  4,
#  0,
#  940,
#  1974,
#  1,
#  371,
#  19,
#  0,
#  1131,
#  25,
#  44,
#  1728,
#  35,
#  5213,
#  15643,
#  2,
#  5,
#  143,
#  1,
#  4,
#  33,
#  1131,
#  73,
#  9711,
#  4,
#  5825,
#  1,
#  50095,
#  66,
#  61,
#  26,
#  17,
#  4,
#  43,
#  567,
#  762,
#  6,
#  175,
#  94,
#  13,
#  118,
#  917,
#  684,
#  1145,
#  78,
#  123,
#  507,
#  13042,
#  5567,
#  310,
#  6,
#  369,
#  6,
#  4106,
#  0,
#  1797,
#  6,
#  118,
#  5464,
#  917,
#  2,
#  153,
#  71,
#  38,
#  4,
#  608,
#  183,
#  19,
#  10,
#  608,
#  199,
#  94,
#  184,
#  11,
#  71,
#  6187,
#  9033,
#  11,
#  7183,
#  71,
#  1225,
#  0,
#  33800,
#  1,
#  0,
#  1797,
#  26185,
#  363,
#  88,
#  391,
#  30,
#  4778,
#  35,
#  1045,
#  66,
#  0,
#  2757,
#  42433,
#  2068,
#  29,
#  948,
#  39,
#  2025,
#  24,
#  55,
#  9929,
#  7088,
#  141,
#  4186,
#  1,
#  29,
#  501,
#  25,
#  3235,
#  63,
#  10270,
#  5233,
#  3244,
#  9606,
#  4,
#  3,
#  ...]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

word_counter = Counter(int_words)
prob = {word:1-np.sqrt(1e-5/(count/len(int_words))) for word,count in word_counter.items()}
train_words = [word for word in int_words if prob[word] < random.random()] # The final subsampled word list

# %%
len(train_words), len(int_words)
# Out:
# (4628701, 16680599)

# %%
random.random()
# Out:
# 0.9381699767411099

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    r = np.random.randint(1,window_size+1)
    
    if idx-r>=0:
        start = idx-r
    else:
        start = 0
    
    end = idx+r
    
    return list(set(words[start:end+1]))

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w,softmax_b,labels,embed,n_sampled,n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-61-2aa168c49a56>:13: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6275 0.3089 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5139 0.3026 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.3732 0.3029 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.4150 0.3034 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.2956 0.3022 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.3107 0.3023 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.2613 0.3026 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.1983 0.3037 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.1355 0.3026 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.1241 0.3020 sec/batch
# Nearest to than: pps, seater, shamanic, maasai, gutar, alzheimer, connolly, buu,
# Nearest to zero: tatars, female, salamat, nanpa, health, hypochlorite, hamas, deuteronomist,
# Nearest to in: dma, period, svante, despair, franchises, patient, trucks, luminous,
# Nearest to been: hymenoptera, mucus, charis, dissolved, athenagoras, abiotic, urbanised, urinating,
# Nearest to while: nonalignment, hurl, bodhisattva, pickle, avogadro, verden, mess, unconditionally,
# Nearest to a: caused, proportione, seam, anode, lfflin, kournikova, promotional, talvela,
# Nearest to have: nyx, corel, zulus, asl, gnumeric, vida, mono, proprietors,
# Nearest to has: improvisational, characteristica, tenochtitlan, peritoneum, swat, interdependence, reassemble, mebyon,
# Nearest to event: rants, sydney, destruct, omitted, purer, mollusk, aimed, infested,
# Nearest to applied: mod, manifest, oli, drained, bedridden, headlines, squaring, undamaged,
# Nearest to bill: lans, paulsen, foreword, responsibilities, fanclub, defaulted, gestapo, wronged,
# Nearest to gold: injectors, chick, majesties, eleventh, sabine, chillout, real, kicks,
# Nearest to scale: foretells, reunify, zangger, studi, ales, response, sonority, highways,
# Nearest to discovered: lump, kepulauan, quarrying, seram, leith, icrm, yemeni, hiroyuki,
# Nearest to professional: gwynn, pedophilia, ahmedabad, announcer, sis, bala, redoutable, lune,
# Nearest to placed: bishvat, witnessed, endo, sounds, prawns, mobilized, arrangement, merneptah,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.1610 0.3073 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.0550 0.3034 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.0134 0.3031 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 4.9265 0.3018 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 4.8447 0.3020 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 4.8541 0.3025 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 4.8013 0.3024 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 4.7485 0.3030 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.7303 0.3143 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.7072 0.3088 sec/batch
# Nearest to than: pps, shamanic, seater, acquire, dominance, dimension, asserted, item,
# Nearest to zero: june, health, female, tatars, salamat, accordance, replacement, southwest,
# Nearest to in: period, dma, franchises, despair, svante, patient, trucks, luminous,
# Nearest to been: dissolved, released, selected, mucus, charis, frf, maintain, extensive,
# Nearest to while: nonalignment, bodhisattva, earn, mess, avogadro, hurl, multiple, artists,
# Nearest to a: caused, seam, implementations, promotional, interfaces, recently, anode, lfflin,
# Nearest to have: adopted, nyx, corel, asl, example, zulus, legalized, vida,
# Nearest to has: improvisational, political, adequate, elicited, involving, global, carbonated, personnel,
# Nearest to event: rants, aimed, purer, sydney, omitted, destruct, omnipotent, lenient,
# Nearest to applied: mod, drained, color, manifest, headlines, qin, oli, myung,
# Nearest to bill: responsibilities, paulsen, lans, foreword, board, england, ordination, grand,
# Nearest to gold: chick, real, injectors, eleventh, chillout, sabine, axes, kicks,
# Nearest to scale: foretells, response, zangger, demolished, playful, reunify, squaw, studi,
# Nearest to discovered: beside, unofficial, seram, yemeni, kepulauan, rotate, grueling, lump,
# Nearest to professional: gwynn, guidelines, sis, practically, pedophilia, announcer, lune, romanized,
# Nearest to placed: bishvat, witnessed, sounds, arrangement, minute, mobilized, endo, choices,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.6631 0.3047 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.6079 0.3021 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.5996 0.3017 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.5848 0.3023 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.5167 0.3020 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.5580 0.3030 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.5093 0.3010 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.4780 0.3022 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.4977 0.3027 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.4733 0.3027 sec/batch
# Nearest to than: pps, shamanic, seater, microsystems, item, standardized, acquire, dilation,
# Nearest to zero: june, female, tatars, health, salamat, pianist, pipelines, swiss,
# Nearest to in: trucks, period, dma, svante, luminous, franchises, recession, patient,
# Nearest to been: dissolved, released, conclude, abiotic, charis, hymenoptera, selected, mucus,
# Nearest to while: nonalignment, mess, earn, bodhisattva, avogadro, hurl, reformation, pickle,
# Nearest to a: interfaces, caused, implementations, seam, anode, lfflin, mediocre, promotional,
# Nearest to have: legalized, nyx, zulus, asl, mit, corel, adopted, keys,
# Nearest to has: improvisational, adequate, hussein, unintended, global, involving, elicited, political,
# Nearest to event: rants, omitted, aimed, sydney, purer, omnipotent, auxiliary, infested,
# Nearest to applied: mod, drained, manifest, color, headlines, unaided, canal, countrymen,
# Nearest to bill: responsibilities, foreword, board, lans, gestapo, ordination, physician, paulsen,
# Nearest to gold: eleventh, injectors, sabine, chick, chillout, horace, mapsto, axes,
# Nearest to scale: foretells, response, demolished, highways, playful, zangger, drafted, maja,
# Nearest to discovered: unofficial, beside, seram, lump, rotate, kepulauan, yemeni, quarrying,
# Nearest to professional: gwynn, guidelines, sis, practically, increasing, romanized, match, announcer,
# Nearest to placed: witnessed, sounds, bishvat, minute, endo, arrangement, mobilized, trips,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.4841 0.3050 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.4701 0.3028 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.4444 0.3024 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.4300 0.3013 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.4559 0.3044 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.3948 0.3025 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.4268 0.3032 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.4423 0.3020 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.3962 0.3026 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.3552 0.3027 sec/batch
# Nearest to than: pps, seater, shamanic, microsystems, item, alzheimer, acquire, maasai,
# Nearest to zero: female, june, deaths, tatars, pianist, salamat, pipelines, total,
# Nearest to in: luminous, trucks, dma, period, prosecute, roughly, svante, recession,
# Nearest to been: dissolved, charis, degradation, conclude, abiotic, hymenoptera, released, confederaci,
# Nearest to while: nonalignment, mess, hurl, earn, pickle, bodhisattva, debilitating, avogadro,
# Nearest to a: implementations, seam, interfaces, koran, caused, anode, almighty, desecration,
# Nearest to have: zulus, nyx, legalized, vida, asl, anemia, serif, mit,
# Nearest to has: improvisational, unintended, hussein, carbonated, tenochtitlan, konix, shyness, raeder,
# Nearest to event: rants, sydney, lenient, omitted, omnipotent, mollusk, purer, infested,
# Nearest to applied: mod, drained, manifest, headlines, color, unaided, canal, countrymen,
# Nearest to bill: lans, responsibilities, gestapo, foreword, paulsen, physician, zachary, board,
# Nearest to gold: sabine, injectors, chick, eleventh, dropouts, fema, chillout, amicable,
# Nearest to scale: foretells, response, demolished, clotting, playful, highways, reunify, oversees,
# Nearest to discovered: lump, unofficial, seram, beside, quarrying, kepulauan, wolves, rotate,
# Nearest to professional: gwynn, romanized, guidelines, announcer, pedophilia, sis, practically, fares,
# Nearest to placed: bishvat, witnessed, sounds, endo, minute, rovere, joshua, merneptah,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.3807 0.3026 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.3757 0.3027 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.3484 0.3028 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.3371 0.3028 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.3326 0.3034 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.3378 0.3018 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.3395 0.2193 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.2607 0.3032 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.2488 0.3036 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.2366 0.3036 sec/batch
# Nearest to than: pps, seater, shamanic, microsystems, alzheimer, item, acquire, recoilless,
# Nearest to zero: female, tatars, june, pianist, deaths, migrant, salamat, swiss,
# Nearest to in: luminous, dma, trucks, patient, recession, peano, period, subconscious,
# Nearest to been: charis, abiotic, degradation, conclude, dissolved, confederaci, released, deepen,
# Nearest to while: nonalignment, mess, hurl, earn, bodhisattva, depended, pickle, multidisciplinary,
# Nearest to a: seam, implementations, kournikova, interfaces, koran, caused, almighty, condoms,
# Nearest to have: zulus, nyx, legalized, serif, vida, asl, anemia, mit,
# Nearest to has: improvisational, unintended, hussein, carbonated, shyness, adequate, raeder, characteristica,
# Nearest to event: rants, sydney, lenient, mollusk, destruct, purer, omitted, omnipotent,
# Nearest to applied: mod, manifest, drained, color, unaided, irreverent, headlines, bedridden,
# Nearest to bill: lans, responsibilities, gestapo, foreword, physician, paulsen, defaulted, england,
# Nearest to gold: sabine, chick, injectors, eleventh, majesties, dropouts, amicable, fema,
# Nearest to scale: foretells, response, clotting, playful, demolished, oversees, cornerstones, encode,
# Nearest to discovered: lump, beside, seram, quarrying, unofficial, kepulauan, wolves, yemeni,
# Nearest to professional: romanized, gwynn, announcer, pedophilia, guidelines, sis, practically, lune,
# Nearest to placed: bishvat, witnessed, sounds, endo, minute, durability, animism, hari,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.2249 0.3058 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.2146 0.3026 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.1813 0.3032 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.2208 0.3031 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.2383 0.3030 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.2049 0.3012 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.1783 0.3028 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.1111 0.3037 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.1602 0.3177 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.1349 0.3016 sec/batch
# Nearest to than: pps, seater, shamanic, recoilless, item, dilation, wagers, per,
# Nearest to zero: female, tatars, migrant, june, three, pipelines, salamat, total,
# Nearest to in: luminous, trucks, patient, recession, certificate, roughly, franchises, subconscious,
# Nearest to been: charis, abiotic, confederaci, conclude, degradation, dissolved, approbation, frf,
# Nearest to while: mess, nonalignment, hurl, earn, bodhisattva, debilitating, unconditionally, multidisciplinary,
# Nearest to a: implementations, seam, headset, kournikova, condoms, interfaces, anode, bright,
# Nearest to have: zulus, vida, serif, nyx, legalized, anemia, asl, adopted,
# Nearest to has: improvisational, carbonated, hussein, unintended, shyness, focussing, adequate, characteristica,
# Nearest to event: rants, lenient, mollusk, purer, sydney, destruct, taken, omitted,
# Nearest to applied: mod, manifest, drained, color, unaided, irreverent, bedridden, oli,
# Nearest to bill: lans, gestapo, paulsen, responsibilities, foreword, physician, quarried, defaulted,
# Nearest to gold: sabine, injectors, dropouts, majesties, chick, ane, civilisations, amicable,
# Nearest to scale: foretells, clotting, response, cornerstones, playful, encode, oversees, reunify,
# Nearest to discovered: lump, seram, beside, quarrying, kepulauan, hiroyuki, wolves, unofficial,
# Nearest to professional: gwynn, romanized, practically, match, announcer, pedophilia, sis, oakland,
# Nearest to placed: bishvat, witnessed, durability, endo, sounds, absentee, minute, animism,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.1406 0.3041 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.1410 0.3033 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.1411 0.3029 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.0934 0.3021 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.1259 0.3027 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.1685 0.3037 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.0880 0.3029 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.0823 0.3031 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.1542 0.3020 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.1029 0.3036 sec/batch
# Nearest to than: pps, shamanic, recoilless, seater, amplifiers, dilation, item, replenished,
# Nearest to zero: female, tatars, three, migrant, salamat, june, total, pipelines,
# Nearest to in: luminous, patient, trucks, prosecute, dma, franchises, subconscious, recession,
# Nearest to been: charis, abiotic, degradation, approbation, confederaci, sorcery, dissolved, conclude,
# Nearest to while: nonalignment, mess, hurl, unconditionally, earn, bodhisattva, verden, multidisciplinary,
# Nearest to a: implementations, seam, headset, anode, kournikova, condoms, bright, interfaces,
# Nearest to have: zulus, vida, serif, legalized, nyx, asl, anemia, pikemen,
# Nearest to has: improvisational, unintended, hussein, shyness, carbonated, focussing, swat, characteristica,
# Nearest to event: rants, lenient, purer, taken, omitted, nick, destruct, mollusk,
# Nearest to applied: mod, manifest, unaided, drained, color, middleware, bedridden, irreverent,
# Nearest to bill: gestapo, lans, foreword, paulsen, responsibilities, defaulted, physician, quarried,
# Nearest to gold: sabine, injectors, chick, majesties, dropouts, fema, eleventh, finest,
# Nearest to scale: foretells, cornerstones, clotting, response, oversees, playful, ccds, encode,
# Nearest to discovered: lump, seram, quarrying, kepulauan, wolves, beside, piers, unofficial,
# Nearest to professional: romanized, gwynn, match, pedophilia, announcer, practically, lune, guidelines,
# Nearest to placed: witnessed, bishvat, minute, absentee, durability, endo, sounds, animism,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.1107 0.3039 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.0977 0.3023 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.0590 0.3034 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.0902 0.3026 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.1467 0.3021 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.1050 0.3033 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.0950 0.3024 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.1169 0.3026 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.0435 0.3027 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.0594 0.3012 sec/batch
# Nearest to than: pps, shamanic, recoilless, replenished, strengthened, moves, amplifiers, seater,
# Nearest to zero: migrant, female, tatars, three, total, deaths, salamat, june,
# Nearest to in: luminous, patient, subconscious, prosecute, roughly, recession, certificate, shifted,
# Nearest to been: charis, confederaci, abiotic, sorcery, dissolved, degradation, hymenoptera, conclude,
# Nearest to while: nonalignment, mess, hurl, unconditionally, verden, earn, multidisciplinary, formed,
# Nearest to a: implementations, headset, seam, expending, kournikova, anode, interfaces, condoms,
# Nearest to have: zulus, nyx, vida, anemia, legalized, serif, asl, fossilized,
# Nearest to has: improvisational, characteristica, unintended, shyness, focussing, hussein, carbonated, swat,
# Nearest to event: rants, lenient, mollusk, destruct, nick, taken, handing, omitted,
# Nearest to applied: mod, manifest, unaided, drained, kinesthetic, irishman, bedridden, middleware,
# Nearest to bill: responsibilities, gestapo, defaulted, lans, board, paulsen, impeachment, coalitions,
# Nearest to gold: sabine, injectors, majesties, dropouts, chick, fema, civilisations, ane,
# Nearest to scale: foretells, cornerstones, clotting, response, playful, global, sonority, highways,
# Nearest to discovered: lump, beside, wolves, seram, nibelungenlied, kepulauan, quarrying, gion,
# Nearest to professional: gwynn, romanized, match, practically, guidelines, pedophilia, losses, ahmedabad,
# Nearest to placed: witnessed, bishvat, minute, absentee, animism, endo, sounds, durability,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.0586 0.3062 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 3.9944 0.3052 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.0868 0.3030 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.0840 0.3022 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.0641 0.3028 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.0167 0.3037 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.0239 0.3025 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.0503 0.3028 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 3.9545 0.3024 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.0111 0.3038 sec/batch
# Nearest to than: pps, shamanic, recoilless, strengthened, moves, replenished, unpredictable, lumped,
# Nearest to zero: migrant, female, deaths, tatars, total, salamat, three, rate,
# Nearest to in: luminous, roughly, certificate, subconscious, patient, recession, prosecute, decreased,
# Nearest to been: charis, confederaci, abiotic, sorcery, released, posthumous, conclude, degradation,
# Nearest to while: nonalignment, mess, hurl, verden, unconditionally, earn, bodhisattva, koh,
# Nearest to a: implementations, headset, expending, seam, mastery, microstate, anode, usaaf,
# Nearest to have: zulus, nyx, vida, anemia, serif, instructive, pikemen, traynor,
# Nearest to has: improvisational, characteristica, shyness, unintended, focussing, swat, hussein, adequate,
# Nearest to event: rants, lenient, destruct, mollusk, handing, hubble, nick, sydney,
# Nearest to applied: mod, expounding, irishman, kinesthetic, unaided, manifest, bedridden, drained,
# Nearest to bill: gestapo, defaulted, impeachment, responsibilities, lans, board, grand, coalitions,
# Nearest to gold: sabine, injectors, majesties, dropouts, fema, ane, yellow, civilisations,
# Nearest to scale: foretells, cornerstones, response, ales, clotting, studi, sonority, global,
# Nearest to discovered: lump, wolves, nibelungenlied, beside, kepulauan, seram, quicksilver, piers,
# Nearest to professional: romanized, gwynn, match, announcer, pedophilia, ahmedabad, oakland, guidelines,
# Nearest to placed: bishvat, absentee, witnessed, minute, animism, durability, sounds, trap,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.0348 0.3051 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.0154 0.3037 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.0830 0.1341 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 3.9832 0.3034 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 3.9470 0.3038 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 3.9449 0.3036 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 3.9372 0.3023 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 3.9604 0.8029 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 3.9509 1.8418 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 3.9029 0.3103 sec/batch
# Nearest to than: pps, shamanic, recoilless, strengthened, moves, replenished, unpredictable, lumped,
# Nearest to zero: migrant, female, total, oct, three, tatars, salamat, deaths,
# Nearest to in: luminous, patient, roughly, recession, decreased, imagery, franchises, subconscious,
# Nearest to been: charis, confederaci, abiotic, sorcery, seizes, released, posthumous, clerks,
# Nearest to while: hurl, nonalignment, mess, unconditionally, earn, gyroscopic, verden, artists,
# Nearest to a: implementations, headset, seam, expending, usaaf, kournikova, anode, mastery,
# Nearest to have: zulus, anemia, nyx, vida, serif, pikemen, instructive, traynor,
# Nearest to has: improvisational, characteristica, unintended, shyness, kyi, focussing, adequate, hussein,
# Nearest to event: rants, lenient, destruct, nick, sydney, handing, mollusk, arena,
# Nearest to applied: mod, unaided, irishman, expounding, kinesthetic, manifest, oli, bedridden,
# Nearest to bill: impeachment, gestapo, defaulted, responsibilities, board, ayers, lans, negatively,
# Nearest to gold: sabine, silver, injectors, majesties, yellow, dropouts, fema, chick,
# Nearest to scale: foretells, cornerstones, clotting, studi, ales, playful, ccds, alpine,
# Nearest to discovered: lump, kepulauan, nibelungenlied, wolves, seram, quicksilver, beside, gion,
# Nearest to professional: romanized, gwynn, match, attendances, oakland, pedophilia, guidelines, ahmedabad,
# Nearest to placed: bishvat, absentee, witnessed, durability, animism, endo, trap, prawns,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 3.9446 0.3082 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 3.9341 0.3019 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 3.9755 0.3001 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 3.8683 0.3009 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 3.8927 0.3003 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 3.8920 0.3012 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 3.9205 0.2994 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 3.8977 0.3004 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 3.9353 0.3007 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 3.9050 0.2992 sec/batch
# Nearest to than: pps, shamanic, recoilless, moves, strengthened, replenished, unpredictable, midrange,
# Nearest to zero: migrant, total, female, oct, salamat, tatars, deaths, three,
# Nearest to in: patient, luminous, imagery, decreased, subconscious, roughly, recession, idiocy,
# Nearest to been: charis, confederaci, abiotic, sorcery, posthumous, conclude, clerks, seizes,
# Nearest to while: hurl, mess, unconditionally, nonalignment, artists, gyroscopic, verden, earn,
# Nearest to a: headset, seam, implementations, expending, sensu, usaaf, anode, proportione,
# Nearest to have: zulus, serif, vida, anemia, nyx, pikemen, traynor, legalized,
# Nearest to has: improvisational, characteristica, unintended, kyi, focussing, shyness, adequate, swat,
# Nearest to event: rants, lenient, destruct, hubble, handing, mollusk, arena, nick,
# Nearest to applied: mod, irishman, expounding, unaided, kinesthetic, manifest, oli, manna,
# Nearest to bill: impeachment, gestapo, defaulted, responsibilities, board, ayers, signed, lans,
# Nearest to gold: sabine, silver, injectors, majesties, dropouts, civilisations, ane, chick,
# Nearest to scale: foretells, cornerstones, clotting, ales, ccds, etz, alpine, sonority,
# Nearest to discovered: lump, nibelungenlied, kepulauan, quicksilver, wolves, beside, seram, pyruvate,
# Nearest to professional: romanized, gwynn, match, attendances, oakland, methodologies, guidelines, pedophilia,
# Nearest to placed: bishvat, absentee, witnessed, durability, trap, animism, redactor, sounds,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 3.9038 0.3020 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 3.9387 0.3005 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 3.9104 0.3015 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 3.8964 0.2996 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 3.8981 0.3011 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 3.9140 0.3011 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 3.9038 0.3014 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 3.8677 0.3000 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 3.8686 0.3009 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 3.9005 0.3001 sec/batch
# Nearest to than: pps, recoilless, shamanic, rather, moves, replenished, strengthened, lumped,
# Nearest to zero: migrant, female, deaths, total, mortality, oct, salamat, rate,
# Nearest to in: patient, imagery, subconscious, decreased, luminous, idiocy, roughly, cristobal,
# Nearest to been: charis, abiotic, confederaci, sorcery, released, seizes, posthumous, clerks,
# Nearest to while: hurl, mess, unconditionally, nonalignment, gyroscopic, verden, artists, earn,
# Nearest to a: headset, expending, implementations, usaaf, sensu, seam, compromise, geocoding,
# Nearest to have: zulus, serif, vida, traynor, anemia, instructive, reptiles, asl,
# Nearest to has: improvisational, characteristica, kyi, shyness, unintended, focussing, swat, hussein,
# Nearest to event: lenient, rants, hubble, destruct, handing, mollusk, blameless, nick,
# Nearest to applied: mod, irishman, expounding, kinesthetic, unaided, manifest, divergence, oli,
# Nearest to bill: impeachment, gestapo, defaulted, signed, board, responsibilities, ayers, outlaw,
# Nearest to gold: silver, sabine, injectors, majesties, fema, yellow, civilisations, dropouts,
# Nearest to scale: cornerstones, foretells, alpine, etz, sonority, clotting, ales, studi,
# Nearest to discovered: lump, nibelungenlied, kepulauan, quicksilver, seram, pyruvate, beside, wolves,
# Nearest to professional: romanized, gwynn, match, attendances, guidelines, ahmedabad, pedophilia, humanitarian,
# Nearest to placed: bishvat, absentee, animism, durability, sounds, trap, witnessed, prawns,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 3.9202 0.3038 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 3.8827 0.3020 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 3.9164 0.3005 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 3.8931 0.3008 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 3.8792 0.3032 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 3.8834 0.3053 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 3.8898 0.3042 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 3.8683 0.3059 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 3.8855 0.3069 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 3.9045 0.3097 sec/batch
# Nearest to than: pps, shamanic, recoilless, replenished, rather, moves, lumped, strengthened,
# Nearest to zero: migrant, deaths, female, total, mortality, five, salamat, oct,
# Nearest to in: imagery, patient, luminous, idiocy, decreased, matheson, svenska, recession,
# Nearest to been: seizes, charis, confederaci, abiotic, impartiality, released, sorcery, seigneurial,
# Nearest to while: hurl, nonalignment, mess, unconditionally, verden, gyroscopic, artists, depended,
# Nearest to a: headset, usaaf, expending, sensu, geocoding, participate, peres, seam,
# Nearest to have: zulus, vida, serif, traynor, petrel, nyx, anemia, reptiles,
# Nearest to has: improvisational, characteristica, shyness, kyi, unintended, focussing, plausibility, claiming,
# Nearest to event: lenient, rants, hubble, destruct, handing, mollusk, blameless, mihi,
# Nearest to applied: mod, expounding, irishman, kinesthetic, manifest, derose, manna, oli,
# Nearest to bill: impeachment, defaulted, signed, responsibilities, gestapo, board, ayers, outlaw,
# Nearest to gold: silver, sabine, injectors, majesties, fema, civilisations, yellow, darryl,
# Nearest to scale: cornerstones, etz, ales, foretells, alpine, studi, reunify, sonority,
# Nearest to discovered: nibelungenlied, lump, kepulauan, quicksilver, impressed, seram, wolves, encampment,
# Nearest to professional: romanized, gwynn, attendances, match, humanitarian, schools, pedophilia, princeton,
# Nearest to placed: bishvat, absentee, animism, prawns, witnessed, durability, trap, milius,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 3.9419 0.3220 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 3.8646 0.3117 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 3.8614 0.3065 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 3.8667 0.3054 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 3.7573 0.3049 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 3.8567 0.3060 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 3.8718 0.3041 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 3.8479 0.3048 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 3.8777 0.0492 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 3.8546 0.3056 sec/batch
# Nearest to than: pps, recoilless, rather, shamanic, moves, strengthened, replenished, spending,
# Nearest to zero: migrant, female, oct, deaths, mortality, total, five, two,
# Nearest to in: patient, luminous, imagery, decreased, recession, subconscious, idiocy, cristobal,
# Nearest to been: abiotic, charis, seizes, released, confederaci, impartiality, sorcery, posthumous,
# Nearest to while: mess, hurl, unconditionally, nonalignment, gyroscopic, depended, widely, earn,
# Nearest to a: headset, usaaf, expending, sensu, geocoding, cisternae, seam, implementations,
# Nearest to have: zulus, anemia, petrel, serif, vida, traynor, deficit, axles,
# Nearest to has: improvisational, kyi, characteristica, shyness, focussing, unintended, clarinets, adequate,
# Nearest to event: lenient, rants, hubble, destruct, handing, blameless, nick, mihi,
# Nearest to applied: mod, expounding, kinesthetic, irishman, interdisciplinary, derose, manna, awareness,
# Nearest to bill: impeachment, defaulted, responsibilities, signed, gestapo, board, mayfield, ayers,
# Nearest to gold: silver, sabine, injectors, majesties, fema, darryl, finest, yellow,
# Nearest to scale: cornerstones, ales, microcode, etz, alpine, albedo, ccds, studi,
# Nearest to discovered: lump, quicksilver, nibelungenlied, kepulauan, impressed, tyrannosaurus, wolves, thymus,
# Nearest to professional: gwynn, schools, romanized, attendances, humanitarian, match, pedophilia, guidelines,
# Nearest to placed: absentee, bishvat, animism, durability, prawns, trap, sounds, orphanage,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 3.7822 0.3084 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 3.7883 0.3056 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 3.8050 0.3046 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 3.7753 0.3046 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 3.8107 0.3049 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 3.7810 0.3048 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 3.7973 0.3048 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 3.8192 0.3038 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 3.8481 0.3050 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 3.7568 0.3051 sec/batch
# Nearest to than: pps, recoilless, rather, shamanic, moves, strengthened, replenished, brahmin,
# Nearest to zero: migrant, female, oct, deaths, total, five, salamat, mortality,
# Nearest to in: luminous, patient, decreased, imagery, idiocy, subconscious, recession, franchises,
# Nearest to been: seizes, abiotic, charis, sorcery, impartiality, confederaci, released, conclude,
# Nearest to while: mess, hurl, unconditionally, nonalignment, gyroscopic, earn, artists, depended,
# Nearest to a: headset, usaaf, seam, expending, geocoding, cisternae, sensu, compromise,
# Nearest to have: zulus, serif, anemia, petrel, occurrence, vida, deficit, reptiles,
# Nearest to has: improvisational, kyi, characteristica, unintended, shyness, focussing, claiming, since,
# Nearest to event: lenient, rants, hubble, handing, destruct, arena, nick, mihi,
# Nearest to applied: mod, irishman, expounding, interdisciplinary, kinesthetic, unaided, manna, understandings,
# Nearest to bill: impeachment, defaulted, ayers, responsibilities, board, signed, mayfield, gestapo,
# Nearest to gold: silver, sabine, majesties, injectors, fema, darryl, civilisations, finest,
# Nearest to scale: cornerstones, ales, microcode, etz, studi, reunify, albedo, sonority,
# Nearest to discovered: lump, nibelungenlied, quicksilver, kepulauan, impressed, tyrannosaurus, thymus, seram,
# Nearest to professional: attendances, gwynn, schools, romanized, match, humanitarian, guidelines, pedophilia,
# Nearest to placed: absentee, bishvat, prawns, durability, trap, animism, sounds, notochord,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 3.7603 0.3075 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 3.7444 0.3038 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.7555 0.3036 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 3.7764 0.3041 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 3.7864 0.3040 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 3.7749 0.3050 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 3.7725 0.3068 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 3.8125 0.3060 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 3.8031 0.3130 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 3.7743 0.3086 sec/batch
# Nearest to than: pps, rather, recoilless, shamanic, replenished, moves, brahmin, strengthened,
# Nearest to zero: migrant, deaths, oct, female, total, five, two, mortality,
# Nearest to in: patient, imagery, idiocy, luminous, subconscious, och, cristobal, takagi,
# Nearest to been: seizes, abiotic, confederaci, charis, impartiality, conclude, sorcery, posthumous,
# Nearest to while: hurl, mess, unconditionally, nonalignment, earn, artists, depended, widely,
# Nearest to a: headset, sensu, cisternae, expending, foci, geocoding, implementations, morningside,
# Nearest to have: zulus, serif, anemia, reptiles, occurrence, asl, vida, traynor,
# Nearest to has: improvisational, unintended, characteristica, kyi, shyness, claiming, focussing, plausibility,
# Nearest to event: lenient, hubble, rants, handing, destruct, arena, blameless, mihi,
# Nearest to applied: mod, irishman, expounding, interdisciplinary, kinesthetic, unaided, derose, understandings,
# Nearest to bill: impeachment, defaulted, signed, ayers, board, responsibilities, gestapo, outlaw,
# Nearest to gold: silver, sabine, darryl, majesties, injectors, fema, finest, yellow,
# Nearest to scale: cornerstones, reunify, microcode, ales, etz, gloucestershire, albedo, harmony,
# Nearest to discovered: quicksilver, nibelungenlied, kepulauan, tyrannosaurus, lump, impressed, telluride, thymus,
# Nearest to professional: schools, attendances, gwynn, guidelines, romanized, humanitarian, pedophilia, methodologies,
# Nearest to placed: absentee, bishvat, trap, notochord, durability, prawns, sounds, animism,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 3.7802 0.3115 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 3.7924 0.3073 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 3.8006 0.3076 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 3.8042 0.3044 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 3.7880 0.3059 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 3.7610 0.3063 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 3.7803 0.3046 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 3.7942 0.3072 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 3.8012 0.7764 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 3.8085 0.3175 sec/batch
# Nearest to than: pps, rather, recoilless, shamanic, brahmin, replenished, moves, git,
# Nearest to zero: migrant, female, deaths, mortality, oct, total, five, salamat,
# Nearest to in: imagery, patient, luminous, idiocy, cristobal, subconscious, decreased, takagi,
# Nearest to been: seizes, charis, impartiality, abiotic, posthumous, sorcery, released, confederaci,
# Nearest to while: hurl, mess, unconditionally, nonalignment, widely, depended, gyroscopic, foil,
# Nearest to a: geocoding, headset, sensu, compromise, cisternae, usaaf, expending, seam,
# Nearest to have: zulus, occurrence, reptiles, petrel, serif, vida, anemia, axles,
# Nearest to has: improvisational, characteristica, kyi, unintended, plausibility, claiming, shyness, focussing,
# Nearest to event: hubble, lenient, rants, handing, destruct, blameless, mihi, arena,
# Nearest to applied: mod, irishman, expounding, kinesthetic, interdisciplinary, understandings, unaided, tempering,
# Nearest to bill: impeachment, defaulted, signed, responsibilities, board, reviewing, ayers, negatively,
# Nearest to gold: silver, sabine, injectors, fema, majesties, yellow, civilisations, darryl,
# Nearest to scale: cornerstones, harmony, reunify, microcode, albedo, ales, etz, ccds,
# Nearest to discovered: nibelungenlied, quicksilver, kepulauan, impressed, tyrannosaurus, sent, lump, lussac,
# Nearest to professional: gwynn, attendances, schools, pedophilia, romanized, match, guidelines, humanitarian,
# Nearest to placed: absentee, bishvat, animism, trap, sounds, prawns, notochord, orphanage,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 3.7618 0.3094 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.7178 0.3082 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 3.7770 0.3087 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 3.8043 0.3125 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 3.8001 0.3127 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 3.8371 0.3114 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 3.8445 0.3105 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 3.7458 0.3100 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 3.7330 0.3095 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 3.7957 0.3549 sec/batch
# Nearest to than: pps, rather, shamanic, recoilless, brahmin, replenished, moves, tractatus,
# Nearest to zero: migrant, female, mortality, deaths, total, rate, male, salamat,
# Nearest to in: imagery, idiocy, patient, cristobal, luminous, takagi, decreased, och,
# Nearest to been: seizes, charis, abiotic, sorcery, impartiality, posthumous, confederaci, lavalas,
# Nearest to while: nonalignment, mess, unconditionally, hurl, depended, widely, earn, verden,
# Nearest to a: headset, geocoding, sensu, usaaf, cisternae, morningside, compromise, implementations,
# Nearest to have: zulus, occurrence, reptiles, petrel, vida, anemia, traynor, axles,
# Nearest to has: improvisational, kyi, characteristica, claiming, shyness, unintended, focussing, plausibility,
# Nearest to event: lenient, hubble, rants, destruct, blameless, mihi, handing, arena,
# Nearest to applied: mod, irishman, kinesthetic, canal, interdisciplinary, expounding, awareness, derose,
# Nearest to bill: impeachment, defaulted, signed, ayers, outlaw, responsibilities, gestapo, mayfield,
# Nearest to gold: silver, sabine, injectors, majesties, fema, darryl, coins, finest,
# Nearest to scale: cornerstones, harmony, gloucestershire, etz, reunify, ales, albedo, chromatic,
# Nearest to discovered: nibelungenlied, quicksilver, kepulauan, lump, tyrannosaurus, impressed, sent, attar,
# Nearest to professional: gwynn, attendances, schools, romanized, pedophilia, colleges, humanitarian, match,
# Nearest to placed: absentee, bishvat, orphanage, sounds, trap, notochord, sunburst, animism,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.7458 0.3087 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 3.7416 0.3067 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 3.7448 0.3064 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 3.7481 0.3060 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 3.7909 0.3100 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 3.7884 0.2745 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.7568 0.3104 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.7510 0.3071 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.7305 0.3073 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.7171 0.3072 sec/batch
# Nearest to than: pps, rather, recoilless, brahmin, shamanic, replenished, tractatus, moves,
# Nearest to zero: migrant, female, oct, deaths, mortality, total, five, salamat,
# Nearest to in: patient, imagery, idiocy, luminous, och, cristobal, matheson, decreased,
# Nearest to been: seizes, abiotic, charis, sorcery, impartiality, have, posthumous, released,
# Nearest to while: mess, hurl, unconditionally, nonalignment, widely, depended, gyroscopic, artists,
# Nearest to a: geocoding, headset, cisternae, sensu, seam, booths, morningside, poised,
# Nearest to have: zulus, occurrence, petrel, anemia, reptiles, axles, been, serif,
# Nearest to has: improvisational, kyi, characteristica, unintended, focussing, claiming, shyness, clarinets,
# Nearest to event: lenient, hubble, rants, destruct, blameless, mihi, arena, alfons,
# Nearest to applied: mod, kinesthetic, expounding, canal, irishman, interdisciplinary, reserve, derose,
# Nearest to bill: impeachment, defaulted, signed, ayers, outlaw, mayfield, reviewing, responsibilities,
# Nearest to gold: silver, sabine, fema, injectors, coins, darryl, majesties, precious,
# Nearest to scale: harmony, cornerstones, chromatic, gloucestershire, albedo, ales, microcode, etz,
# Nearest to discovered: quicksilver, kepulauan, nibelungenlied, lump, impressed, tyrannosaurus, sent, attar,
# Nearest to professional: gwynn, attendances, pedophilia, romanized, schools, humanitarian, colleges, coen,
# Nearest to placed: bishvat, sounds, absentee, notochord, trap, orphanage, durability, broderick,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.7252 0.3115 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.6771 0.3085 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.7474 0.3069 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.7410 0.3061 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.7252 0.3053 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.7141 0.3052 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.6584 0.3055 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.6682 0.3041 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.6922 0.3048 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.6875 0.3039 sec/batch
# Nearest to than: pps, rather, recoilless, shamanic, replenished, brahmin, per, less,
# Nearest to zero: migrant, female, total, deaths, mortality, oct, five, rate,
# Nearest to in: patient, idiocy, luminous, cristobal, och, decreased, imagery, subconscious,
# Nearest to been: seizes, have, impartiality, charis, abiotic, sorcery, lavalas, invention,
# Nearest to while: unconditionally, hurl, mess, widely, nonalignment, depended, gyroscopic, earn,
# Nearest to a: geocoding, cisternae, headset, seam, compromise, gaits, sensu, morningside,
# Nearest to have: occurrence, zulus, petrel, reptiles, been, anemia, vida, presbyterians,
# Nearest to has: improvisational, kyi, unintended, characteristica, claiming, focussing, shyness, plausibility,
# Nearest to event: hubble, lenient, destruct, rants, alfons, mihi, arena, blameless,
# Nearest to applied: mod, kinesthetic, expounding, irishman, interdisciplinary, canal, wards, tempering,
# Nearest to bill: impeachment, defaulted, signed, ayers, reviewing, outlaw, mayfield, negatively,
# Nearest to gold: silver, sabine, precious, coins, alloys, injectors, fema, majesties,
# Nearest to scale: cornerstones, harmony, chromatic, albedo, gloucestershire, ales, microcode, richter,
# Nearest to discovered: quicksilver, kepulauan, tyrannosaurus, nibelungenlied, lump, thymus, impressed, sent,
# Nearest to professional: gwynn, attendances, pedophilia, schools, romanized, humanitarian, methodologies, guidelines,
# Nearest to placed: bishvat, sounds, absentee, notochord, trap, durability, orphanage, sunburst,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.7301 0.3069 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.7487 0.3039 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.6593 0.3039 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.7528 0.3067 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 3.7379 0.3040 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.6749 0.3042 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.7333 0.3040 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.7310 0.3253 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.6913 0.3053 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.7068 0.3036 sec/batch
# Nearest to than: pps, rather, recoilless, replenished, shamanic, brahmin, less, lumped,
# Nearest to zero: migrant, oct, deaths, female, mortality, total, five, two,
# Nearest to in: patient, cristobal, boi, imagery, och, takagi, quashed, subconscious,
# Nearest to been: seizes, have, impartiality, eastenders, charis, posthumous, abiotic, lavalas,
# Nearest to while: unconditionally, hurl, mess, depended, nonalignment, widely, earn, gyroscopic,
# Nearest to a: geocoding, headset, cisternae, expending, morningside, compromise, sensu, booths,
# Nearest to have: occurrence, zulus, been, anemia, vida, petrel, reptiles, serif,
# Nearest to has: improvisational, unintended, kyi, characteristica, claiming, plausibility, shyness, lozenge,
# Nearest to event: hubble, lenient, arena, destruct, blameless, mihi, rants, horizon,
# Nearest to applied: mod, kinesthetic, irishman, expounding, tempering, understandings, wards, interdisciplinary,
# Nearest to bill: impeachment, defaulted, signed, ayers, outlaw, negatively, mayfield, ftc,
# Nearest to gold: silver, sabine, precious, coins, fema, darryl, majesties, medal,
# Nearest to scale: cornerstones, harmony, albedo, gloucestershire, richter, chromatic, etz, ales,
# Nearest to discovered: quicksilver, tyrannosaurus, impressed, kepulauan, thymus, berzelius, lump, nibelungenlied,
# Nearest to professional: gwynn, attendances, pedophilia, romanized, guidelines, schools, match, basketball,
# Nearest to placed: bishvat, sounds, absentee, notochord, trap, broderick, durability, orphanage,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.7393 0.3066 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.7042 0.3069 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.6893 0.3048 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.7057 0.3053 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.7480 0.3046 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.7255 0.3050 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.7065 0.3040 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.6771 0.3042 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.6734 0.3035 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 3.7087 0.3072 sec/batch
# Nearest to than: pps, rather, recoilless, brahmin, shamanic, less, replenished, lumped,
# Nearest to zero: migrant, female, deaths, mortality, male, total, five, rate,
# Nearest to in: cristobal, patient, recession, imagery, och, enrollments, quashed, idiocy,
# Nearest to been: seizes, have, eastenders, charis, invention, impartiality, rationally, lavalas,
# Nearest to while: widely, nonalignment, unconditionally, depended, mess, earn, hurl, materially,
# Nearest to a: geocoding, headset, participate, compromise, expending, cisternae, booths, sensu,
# ...
# Nearest to professional: punitive, pedophilia, basketball, romana, amyotrophic, coen, kittiwakes, ineligible,
# Nearest to placed: bishvat, notochord, broderick, sunburst, absentee, microfibrils, wreath, hemingway,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.5471 0.3070 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.5750 0.3041 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.5798 0.3035 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.5556 0.3056 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.5837 0.3039 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.5887 0.3041 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.5732 0.3041 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.5708 0.3042 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.6155 0.3045 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.5434 0.3044 sec/batch
# Nearest to than: rather, pps, more, less, larger, higher, flavors, tractatus,
# Nearest to zero: migrant, male, deaths, total, female, rate, press, oct,
# Nearest to in: quashed, enrollments, idiocy, patient, despoja, imagery, cristobal, boi,
# Nearest to been: have, seizes, since, desi, has, eastenders, deaf, lavalas,
# Nearest to while: corresponds, widely, unpopularity, fief, taught, materially, depended, unconditionally,
# Nearest to a: geocoding, gaits, sensu, cleanly, reactivated, illawarra, expending, cisternae,
# Nearest to have: been, occurrence, skynyrd, zulus, petrel, barth, likely, blesses,
# Nearest to has: since, unintended, claiming, been, llama, significance, kyi, recently,
# Nearest to event: hubble, horizon, lenient, valentinian, events, fingerspelling, destruct, sporting,
# Nearest to applied: mod, zhaozhou, drainage, stahl, isaacson, subhash, oakenfold, armpit,
# Nearest to bill: impeachment, signed, ftc, intention, deposit, closing, impeachments, reviewing,
# Nearest to gold: silver, precious, mined, coins, medal, medals, medalist, originating,
# Nearest to scale: survive, richter, albedo, studi, gloucestershire, sonority, chromatic, tb,
# Nearest to discovered: quicksilver, berzelius, himalia, tyrannosaurus, extrasolar, impressed, sent, kummer,
# Nearest to professional: basketball, pedophilia, coen, punitive, romana, amyotrophic, disciplines, ineligible,
# Nearest to placed: bishvat, notochord, sunburst, broderick, microfibrils, absentee, wreath, family,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.5974 0.3071 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.5635 0.3050 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.5392 0.3048 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.5426 0.3186 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.6228 0.3070 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.5254 0.3061 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.6726 0.3056 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.6261 0.3046 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.6450 0.3045 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.5547 0.3054 sec/batch
# Nearest to than: rather, pps, less, more, higher, flavors, larger, tractatus,
# Nearest to zero: male, deaths, total, migrant, rate, female, approximately, estimates,
# Nearest to in: enrollments, quashed, despoja, imagery, patient, idiocy, cristobal, matheson,
# Nearest to been: have, seizes, since, desi, has, deaf, eastenders, watched,
# Nearest to while: corresponds, widely, unpopularity, ambushed, unconditionally, materially, fief, taught,
# Nearest to a: geocoding, gaits, reactivated, illawarra, cleanly, expending, sensu, maui,
# Nearest to have: been, occurrence, skynyrd, zulus, blesses, petrel, likely, anemia,
# Nearest to has: unintended, since, claiming, been, significance, recently, flare, kyi,
# Nearest to event: hubble, lenient, horizon, valentinian, events, destruct, fingerspelling, mihi,
# Nearest to applied: mod, stahl, drainage, isaacson, zhaozhou, oakenfold, panamanian, practical,
# Nearest to bill: impeachment, signed, ftc, deposit, closing, intention, impeachments, reviewing,
# Nearest to gold: silver, precious, mined, coins, medal, medals, medalist, originating,
# Nearest to scale: survive, richter, chromatic, albedo, studi, gloucestershire, diatonic, prestwich,
# Nearest to discovered: quicksilver, tyrannosaurus, berzelius, himalia, sent, impressed, kummer, attar,
# Nearest to professional: basketball, pedophilia, punitive, amyotrophic, romana, disciplines, universiteit, kramer,
# Nearest to placed: bishvat, notochord, sunburst, absentee, broderick, family, politeia, microfibrils,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.5083 0.3059 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.5794 0.3045 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.5116 0.3054 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.5826 0.3048 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.5405 0.3045 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.5551 0.3044 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.6477 0.1465 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.5514 0.3047 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.5345 0.3057 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.5652 0.3057 sec/batch
# Nearest to than: rather, pps, more, less, flavors, larger, higher, bottlenecks,
# Nearest to zero: male, deaths, migrant, female, total, rate, oct, estimates,
# Nearest to in: enrollments, quashed, patient, imagery, despoja, cristobal, beltane, idiocy,
# Nearest to been: have, seizes, since, desi, has, eastenders, deaf, natural,
# Nearest to while: corresponds, widely, materially, unpopularity, fief, ambushed, unconditionally, depended,
# Nearest to a: geocoding, gaits, illawarra, reactivated, sensu, lleida, cleanly, hippodrome,
# Nearest to have: been, occurrence, skynyrd, zulus, blesses, petrel, anemia, presbyterians,
# Nearest to has: unintended, been, since, claiming, recently, significance, flare, llama,
# Nearest to event: hubble, lenient, horizon, valentinian, events, destruct, fingerspelling, mihi,
# Nearest to applied: mod, stahl, drainage, zhaozhou, cubewanos, isaacson, legally, subhash,
# Nearest to bill: impeachment, signed, closing, deposit, ftc, intention, impeachments, defaulted,
# Nearest to gold: silver, precious, mined, medals, coins, medalist, medal, originating,
# Nearest to scale: richter, survive, chromatic, gloucestershire, diatonic, albedo, studi, prestwich,
# Nearest to discovered: quicksilver, tyrannosaurus, berzelius, sent, himalia, impressed, attar, thymus,
# Nearest to professional: basketball, pedophilia, punitive, romana, amyotrophic, wrestler, universiteit, kramer,
# Nearest to placed: bishvat, notochord, sunburst, broderick, family, microfibrils, absentee, multiplan,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.5404 0.3074 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.5324 0.3055 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.5557 0.3044 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.4974 0.3049 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.5792 0.3047 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.5672 0.3043 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.5549 0.3046 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.4865 0.3062 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.5252 0.3053 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.5329 0.3043 sec/batch
# Nearest to than: rather, pps, more, less, bottlenecks, flavors, larger, higher,
# Nearest to zero: deaths, male, total, migrant, female, rate, approximately, oct,
# Nearest to in: quashed, patient, despoja, cristobal, enrollments, imagery, bulldogs, subconscious,
# Nearest to been: have, since, seizes, has, desi, natural, rationally, lavalas,
# Nearest to while: corresponds, widely, materially, unconditionally, fief, snafu, taught, ambushed,
# Nearest to a: geocoding, gaits, reactivated, illawarra, cleanly, foci, cisternae, sensu,
# Nearest to have: been, occurrence, skynyrd, zulus, presbyterians, blesses, likely, barth,
# Nearest to has: unintended, been, since, claiming, recently, significance, kyi, allege,
# Nearest to event: hubble, horizon, lenient, valentinian, events, fingerspelling, sporting, regulator,
# Nearest to applied: mod, stahl, drainage, zhaozhou, cubewanos, legally, isaacson, understandings,
# Nearest to bill: impeachment, signed, closing, deposit, crabs, ftc, intention, performer,
# Nearest to gold: silver, precious, medals, mined, medal, medalist, coins, originating,
# Nearest to scale: survive, richter, chromatic, studi, gloucestershire, albedo, diatonic, prestwich,
# Nearest to discovered: quicksilver, tyrannosaurus, berzelius, himalia, sent, attar, discovery, kummer,
# Nearest to professional: basketball, punitive, universiteit, romana, amyotrophic, pedophilia, wrestler, kittiwakes,
# Nearest to placed: bishvat, notochord, sunburst, microfibrils, family, broderick, hemingway, absentee,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.5092 0.3068 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.5475 0.3042 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.5717 0.3048 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.5431 0.3045 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.5215 0.3038 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.5870 0.3044 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.5554 0.3049 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.5386 0.3039 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.5410 0.3044 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.5838 0.3045 sec/batch
# Nearest to than: rather, more, pps, less, larger, flavors, bottlenecks, carly,
# Nearest to zero: deaths, male, total, migrant, rate, female, oct, approximately,
# Nearest to in: quashed, enrollments, despoja, cristobal, imagery, patient, idiocy, subconscious,
# Nearest to been: have, since, seizes, has, desi, natural, deaf, eastenders,
# Nearest to while: corresponds, fief, widely, materially, snafu, unpopularity, unconditionally, taught,
# Nearest to a: geocoding, gaits, reactivated, illawarra, expending, cleanly, morton, foci,
# Nearest to have: been, occurrence, skynyrd, zulus, blesses, presbyterians, likely, anemia,
# Nearest to has: unintended, been, since, claiming, significance, recently, satisfaction, llama,
# Nearest to event: hubble, horizon, lenient, events, valentinian, fingerspelling, alvarez, extinction,
# Nearest to applied: stahl, mod, drainage, zhaozhou, legally, isaacson, warbler, safer,
# Nearest to bill: impeachment, signed, closing, deposit, crabs, intention, ftc, impeachments,
# Nearest to gold: silver, precious, medals, medal, mined, medalist, originating, coins,
# Nearest to scale: survive, richter, gloucestershire, chromatic, diatonic, albedo, studi, microcode,
# Nearest to discovered: quicksilver, berzelius, tyrannosaurus, discovery, himalia, sent, attar, kummer,
# Nearest to professional: punitive, basketball, universiteit, amyotrophic, glossary, wrestler, requiem, kittiwakes,
# Nearest to placed: bishvat, notochord, microfibrils, broderick, sunburst, family, lumet, multiplan,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.6160 0.3080 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.5335 0.3036 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.5279 0.3120 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.5704 0.3116 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.5949 0.3044 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.5834 0.3062 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.5475 0.3044 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.5406 0.3056 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.5683 0.3050 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.5569 0.3037 sec/batch
# Nearest to than: rather, more, less, pps, larger, flavors, bottlenecks, carly,
# Nearest to zero: total, female, male, migrant, deaths, rate, approximately, population,
# Nearest to in: quashed, enrollments, imagery, patient, despoja, cristobal, idiocy, stoves,
# Nearest to been: have, since, desi, seizes, has, deaf, natural, eastenders,
# Nearest to while: corresponds, fief, widely, materially, unpopularity, snafu, characterise, taught,
# Nearest to a: geocoding, gaits, reactivated, illawarra, cisternae, cleanly, lleida, expending,
# Nearest to have: been, occurrence, skynyrd, zulus, presbyterians, blesses, likely, petrel,
# Nearest to has: unintended, since, been, claiming, recently, significance, allege, satisfaction,
# Nearest to event: hubble, horizon, lenient, valentinian, events, extinction, fingerspelling, regulator,
# Nearest to applied: mod, stahl, legally, drainage, zhaozhou, warbler, isaacson, oakenfold,
# Nearest to bill: impeachment, signed, deposit, closing, intention, ftc, crabs, clinton,
# Nearest to gold: silver, precious, medals, mined, medal, medalist, originating, coins,
# Nearest to scale: survive, richter, chromatic, gloucestershire, diatonic, albedo, prestwich, microcode,
# Nearest to discovered: quicksilver, berzelius, tyrannosaurus, discovery, himalia, sent, attar, morita,
# Nearest to professional: basketball, punitive, wrestler, universiteit, glossary, amyotrophic, requiem, romana,
# Nearest to placed: bishvat, microfibrils, family, notochord, sunburst, politeia, lumet, broderick,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.5889 0.3072 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.5454 0.3059 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.6059 0.3054 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.6290 0.3045 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.5901 0.3044 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.5675 0.3050 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.4920 0.3044 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.5507 0.3035 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.4443 0.3040 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.5954 0.3059 sec/batch
# Nearest to than: rather, more, less, pps, flavors, larger, bottlenecks, carly,
# Nearest to zero: male, female, total, deaths, migrant, rate, population, years,
# Nearest to in: enrollments, quashed, despoja, imagery, cristobal, patient, idiocy, heysel,
# Nearest to been: have, desi, since, has, seizes, deaf, natural, watched,
# Nearest to while: corresponds, widely, injurious, unconditionally, unpopularity, fief, snafu, materially,
# Nearest to a: geocoding, illawarra, gaits, reactivated, cleanly, lleida, expending, khanomtom,
# Nearest to have: been, occurrence, skynyrd, zulus, blesses, presbyterians, anemia, likely,
# Nearest to has: unintended, been, since, recently, kyi, significance, claiming, allege,
# Nearest to event: hubble, lenient, horizon, valentinian, events, destruct, sporting, fingerspelling,
# Nearest to applied: mod, stahl, legally, drainage, zhaozhou, warbler, isaacson, labels,
# Nearest to bill: impeachment, signed, deposit, closing, crabs, intention, ftc, clinton,
# Nearest to gold: silver, precious, medals, mined, medal, medalist, originating, coins,
# Nearest to scale: richter, survive, gloucestershire, chromatic, diatonic, prestwich, albedo, studi,
# Nearest to discovered: quicksilver, tyrannosaurus, berzelius, discovery, sent, lippisch, expeditions, attar,
# Nearest to professional: wrestler, basketball, punitive, amyotrophic, universiteit, requiem, athlete, kramer,
# Nearest to placed: bishvat, notochord, sunburst, microfibrils, wreath, broderick, digital, family,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.5596 0.3074 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.5430 0.3041 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE


# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
